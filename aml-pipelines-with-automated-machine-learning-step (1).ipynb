# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.19.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-132152
# aml-quickstarts-132152
# southcentralus
# 5a4ab2ba-6c51-4805-8155-58759ad589d8

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'bankmarketing-experiment'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: bankmarketing-experiment,
# Workspace: quick-starts-ws-132152)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "auto-ml"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Creating
# Succeeded...............................................................................................................
# AmlCompute wait for completion finished
#
# Wait timeout has been reached
# Current provisioning state of AmlCompute is "Succeeded" and current node count is "0"

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "Bank-marketing"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [8ff61268][5432786c-2f69-41bc-8898-cc37cacbaa48], (This step will run and generate new outputs)
# Submitted PipelineRun a685a2ee-9425-47a7-88e3-ad98559db4a5
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/bankmarketing-experiment/runs/a685a2ee-9425-47a7-88e3-ad98559db4a5?wsid=/subscriptions/5a4ab2ba-6c51-4805-8155-58759ad589d8/resourcegroups/aml-quickstarts-132152/workspaces/quick-starts-ws-132152

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: a685a2ee-9425-47a7-88e3-ad98559db4a5
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/bankmarketing-experiment/runs/a685a2ee-9425-47a7-88e3-ad98559db4a5?wsid=/subscriptions/5a4ab2ba-6c51-4805-8155-58759ad589d8/resourcegroups/aml-quickstarts-132152/workspaces/quick-starts-ws-132152
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'a685a2ee-9425-47a7-88e3-ad98559db4a5', 'status': 'Completed', 'startTimeUtc': '2020-12-28T14:44:05.620849Z', 'endTimeUtc': '2020-12-28T15:30:18.664246Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg132152.blob.core.windows.net/azureml/ExperimentRun/dcid.a685a2ee-9425-47a7-88e3-ad98559db4a5/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=mU1CITQe9X1dpbLbzK7VOkeFGMNXQ2xiSHk3ROgCczs%3D&st=2020-12-28T15%3A35%3A20Z&se=2020-12-28T23%3A45%3A20Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg132152.blob.core.windows.net/azureml/ExperimentRun/dcid.a685a2ee-9425-47a7-88e3-ad98559db4a5/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=NzDjzntZku58lZhQoyS5zncND5wdUXmfihepB7Mc58o%3D&st=2020-12-28T15%3A35%3A20Z&se=2020-12-28T23%3A45%3A20Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg132152.blob.core.windows.net/azureml/ExperimentRun/dcid.a685a2ee-9425-47a7-88e3-ad98559db4a5/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=MzZQMUv1eMEwGk188tmBnmo5raQdP%2BX2OGehx3al7Uo%3D&st=2020-12-28T15%3A35%3A20Z&se=2020-12-28T23%3A45%3A20Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/3f4389c6-7f46-40f8-ae8e-d4da0defd000/metrics_data
# Downloaded azureml/3f4389c6-7f46-40f8-ae8e-d4da0defd000/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  3f4389c6-7f46-40f8-ae8e-d4da0defd000_11  \
# recall_score_micro                                   [0.664339908952959]
# recall_score_weighted                                [0.664339908952959]
# f1_score_weighted                                    [0.726022603050794]
# precision_score_micro                                [0.664339908952959]
# norm_macro_recall                                   [0.5983269333718626]
# AUC_macro                                            [0.902611295422592]
# AUC_weighted                                        [0.9026112954225919]
# precision_score_weighted                            [0.9108173556636415]
# f1_score_micro                                       [0.664339908952959]
# f1_score_macro                                      [0.5807899614226502]
# recall_score_macro                                  [0.7991634666859313]
# accuracy                                             [0.664339908952959]
# balanced_accuracy                                   [0.7991634666859313]
# log_loss                                           [0.48514666762874936]
# AUC_micro                                           [0.8315800138619927]
# average_precision_score_weighted                    [0.9301264576470298]
# matthews_correlation                               [0.37996928237151945]
# average_precision_score_micro                       [0.8497968290388962]
# weighted_accuracy                                   [0.6308668664833909]
# average_precision_score_macro                       [0.7332848945206295]
# precision_score_macro                               [0.6206503062901538]
#
#                                  3f4389c6-7f46-40f8-ae8e-d4da0defd000_9  \
# recall_score_micro                                 [0.7250379362670714]
# recall_score_weighted                              [0.7250379362670714]
# f1_score_weighted                                  [0.7736072215742839]
# precision_score_micro                              [0.7250379362670714]
# norm_macro_recall                                 [0.46774549085203754]
# AUC_macro                                          [0.8402760411746291]
# AUC_weighted                                       [0.8402760411746292]
# precision_score_weighted                           [0.8785390703744637]
# f1_score_micro                                     [0.7250379362670715]
# f1_score_macro                                     [0.6006383322559793]
# recall_score_macro                                 [0.7338727454260188]
# accuracy                                           [0.7250379362670714]
# balanced_accuracy                                  [0.7338727454260188]
# log_loss                                           [0.5503528301778923]
# AUC_micro                                          [0.8265904333829939]
# average_precision_score_weighted                    [0.917112541200144]
# matthews_correlation                               [0.3137224853728785]
# average_precision_score_micro                      [0.8015828365422673]
# weighted_accuracy                                  [0.7228444921304488]
# average_precision_score_macro                      [0.7189056842603938]
# precision_score_macro                               [0.605208708318334]
#
#                                  3f4389c6-7f46-40f8-ae8e-d4da0defd000_18  \
# recall_score_micro                                  [0.7371775417298938]
# recall_score_weighted                               [0.7371775417298938]
# f1_score_weighted                                   [0.7827997126072599]
# precision_score_micro                               [0.7371775417298938]
# norm_macro_recall                                   [0.4766795036371416]
# AUC_macro                                           [0.8303681413437511]
# AUC_weighted                                         [0.830368141343751]
# precision_score_weighted                            [0.8794695291825572]
# f1_score_micro                                      [0.7371775417298938]
# f1_score_macro                                      [0.6097197557327416]
# recall_score_macro                                  [0.7383397518185708]
# accuracy                                            [0.7371775417298938]
# balanced_accuracy                                   [0.7383397518185708]
# log_loss                                            [0.5844838753786756]
# AUC_micro                                           [0.8180270377935023]
# average_precision_score_weighted                    [0.9121462372790377]
# matthews_correlation                                [0.3231844638144878]
# average_precision_score_micro                       [0.7977512844138583]
# weighted_accuracy                                   [0.7368889964021262]
# average_precision_score_macro                       [0.7102919262895333]
# precision_score_macro                               [0.6095580960101088]
#
#                                  3f4389c6-7f46-40f8-ae8e-d4da0defd000_42  \
# recall_score_micro                                  [0.9101669195751139]
# recall_score_weighted                               [0.9101669195751139]
# f1_score_weighted                                   [0.9062564016191513]
# precision_score_micro                               [0.9101669195751139]
# norm_macro_recall                                  [0.47018229239025144]
# AUC_macro                                           [0.9449177266892286]
# AUC_weighted                                        [0.9449177266892287]
# precision_score_weighted                            [0.9037763708978234]
# f1_score_micro                                      [0.9101669195751139]
# f1_score_macro                                      [0.7547534559616343]
# recall_score_macro                                  [0.7350911461951257]
# accuracy                                            [0.9101669195751139]
# balanced_accuracy                                   [0.7350911461951257]
# log_loss                                           [0.17885927334645302]
# AUC_micro                                           [0.9796979375105058]
# average_precision_score_weighted                    [0.9537973953270833]
# matthews_correlation                                [0.5131147560534912]
# average_precision_score_micro                        [0.980661339652372]
# weighted_accuracy                                    [0.953633498385826]
# average_precision_score_macro                       [0.8179717029175477]
# precision_score_macro                               [0.7799836968991016]
#
#                                  3f4389c6-7f46-40f8-ae8e-d4da0defd000_28  \
# recall_score_micro                                  [0.9095599393019727]
# recall_score_weighted                               [0.9095599393019727]
# f1_score_weighted                                   [0.9056229989273888]
# precision_score_micro                               [0.9095599393019727]
# norm_macro_recall                                    [0.467130501790322]
# AUC_macro                                            [0.936974735434299]
# AUC_weighted                                        [0.9369747354342992]
# precision_score_weighted                            [0.9031099784976268]
# f1_score_micro                                      [0.9095599393019727]
# f1_score_macro                                      [0.7530963847181319]
# recall_score_macro                                   [0.733565250895161]
# accuracy                                            [0.9095599393019727]
# balanced_accuracy                                    [0.733565250895161]
# log_loss                                           [0.21120883602694412]
# AUC_micro                                           [0.9777519163859344]
# average_precision_score_weighted                    [0.9514164550708032]
# matthews_correlation                                [0.5097843056844473]
# average_precision_score_micro                       [0.9787484879520854]
# weighted_accuracy                                   [0.9532546598576143]
# average_precision_score_macro                       [0.8115701418984327]
# precision_score_macro                               [0.7781664195831348]
#
#                                  3f4389c6-7f46-40f8-ae8e-d4da0defd000_45  \
# recall_score_micro                                  [0.9125948406676783]
# recall_score_weighted                               [0.9125948406676783]
# f1_score_weighted                                   [0.9087900123862012]
# precision_score_micro                               [0.9125948406676783]
# norm_macro_recall                                   [0.4823894547899683]
# AUC_macro                                           [0.9419946762693874]
# AUC_weighted                                        [0.9419946762693874]
# precision_score_weighted                            [0.9064419404986112]
# f1_score_micro                                      [0.9125948406676783]
# f1_score_macro                                      [0.7613817409356443]
# recall_score_macro                                  [0.7411947273949842]
# accuracy                                            [0.9125948406676783]
# balanced_accuracy                                   [0.7411947273949842]
# log_loss                                           [0.18391451397106756]
# AUC_micro                                           [0.9786549261883435]
# average_precision_score_weighted                      [0.95165795607658]
# matthews_correlation                                [0.5264365575296669]
# average_precision_score_micro                       [0.9796825297262648]
# weighted_accuracy                                    [0.955148852498673]
# average_precision_score_macro                       [0.8097447303507264]
# precision_score_macro                               [0.7872528061629692]
#
#                                  3f4389c6-7f46-40f8-ae8e-d4da0defd000_49  \
# recall_score_micro                                  [0.9019726858877086]
# recall_score_weighted                               [0.9019726858877086]
# f1_score_weighted                                   [0.8877325186057228]
# precision_score_micro                               [0.9019726858877086]
# norm_macro_recall                                   [0.2951762258565853]
# AUC_macro                                            [0.914753624638092]
# AUC_weighted                                         [0.914753624638092]
# precision_score_weighted                            [0.8857779387955127]
# f1_score_micro                                      [0.9019726858877086]
# f1_score_macro                                      [0.6843129222926626]
# recall_score_macro                                  [0.6475881129282927]
# accuracy                                            [0.9019726858877086]
# balanced_accuracy                                   [0.6475881129282927]
# log_loss                                           [0.22130172318375396]
# AUC_micro                                           [0.9718837342642206]
# average_precision_score_weighted                     [0.936358230108936]
# matthews_correlation                                [0.3993228083655445]
# average_precision_score_micro                       [0.9728813081315919]
# weighted_accuracy                                   [0.9651294943672633]
# average_precision_score_macro                       [0.7559316123982631]
# precision_score_macro                               [0.7701076362403594]
#
#                                  3f4389c6-7f46-40f8-ae8e-d4da0defd000_61  \
# recall_score_micro                                   [0.903793626707132]
# recall_score_weighted                                [0.903793626707132]
# f1_score_weighted                                   [0.8876157986677813]
# precision_score_micro                                [0.903793626707132]
# norm_macro_recall                                  [0.28064896165024544]
# AUC_macro                                           [0.9331921822294096]
# AUC_weighted                                        [0.9331921822294095]
# precision_score_weighted                            [0.8878193426760689]
# f1_score_micro                                       [0.903793626707132]
# f1_score_macro                                      [0.6797429027048688]
# recall_score_macro                                  [0.6403244808251227]
# accuracy                                             [0.903793626707132]
# balanced_accuracy                                   [0.6403244808251227]
# log_loss                                              [0.20592086022953]
# AUC_micro                                            [0.976290097885931]
# average_precision_score_weighted                    [0.9480322314186995]
# matthews_correlation                               [0.40009609460892764]
# average_precision_score_micro                       [0.9774118115336541]
# weighted_accuracy                                    [0.969205888909827]
# average_precision_score_macro                       [0.7979370402655044]
# precision_score_macro                               [0.7851905882352941]
#
#                                  3f4389c6-7f46-40f8-ae8e-d4da0defd000_10  \
# recall_score_micro                                   [0.723823975720789]
# recall_score_weighted                                [0.723823975720789]
# f1_score_weighted                                    [0.772607694958718]
# precision_score_micro                                [0.723823975720789]
# norm_macro_recall                                   [0.4616419096521791]
# AUC_macro                                           [0.8578824185371041]
# AUC_weighted                                         [0.857882418537104]
# precision_score_weighted                            [0.8775286621312084]
# f1_score_micro                                       [0.723823975720789]
# f1_score_macro                                       [0.598875146084924]
# recall_score_macro                                  [0.7308209548260896]
# accuracy                                             [0.723823975720789]
# balanced_accuracy                                   [0.7308209548260896]
# log_loss                                            [0.5499676297342101]
# AUC_micro                                            [0.837603855568169]
# average_precision_score_weighted                    [0.9215940734377113]
# matthews_correlation                               [0.30962874058828044]
# average_precision_score_micro                       [0.8362599591262188]
# weighted_accuracy                                   [0.7220868150740254]
# average_precision_score_macro                       [0.7198939222146216]
# precision_score_macro                               [0.6038358465661373]
#
#                                  3f4389c6-7f46-40f8-ae8e-d4da0defd000_21  ...  \
# recall_score_micro                                  [0.9125948406676783]  ...
# recall_score_weighted                               [0.9125948406676783]  ...
# f1_score_weighted                                   [0.9086613440609772]  ...
# precision_score_micro                               [0.9125948406676783]  ...
# norm_macro_recall                                   [0.4800211911893555]  ...
# AUC_macro                                            [0.943998021661693]  ...
# AUC_weighted                                         [0.943998021661693]  ...
# precision_score_weighted                            [0.9062798949414683]  ...
# f1_score_micro                                      [0.9125948406676783]  ...
# f1_score_macro                                      [0.7607503025413473]  ...
# recall_score_macro                                  [0.7400105955946777]  ...
# accuracy                                            [0.9125948406676783]  ...
# balanced_accuracy                                   [0.7400105955946777]  ...
# log_loss                                           [0.17981385781039308]  ...
# AUC_micro                                           [0.9792565642982309]  ...
# average_precision_score_weighted                    [0.9525161907226625]  ...
# matthews_correlation                                [0.5254139610791995]  ...
# average_precision_score_micro                       [0.9802395848606664]  ...
# weighted_accuracy                                   [0.9554428403944659]  ...
# average_precision_score_macro                       [0.8126929119384294]  ...
# precision_score_macro                                 [0.78754962860383]  ...
#
#                                  3f4389c6-7f46-40f8-ae8e-d4da0defd000_6  \
# recall_score_micro                                  [0.898937784522003]
# recall_score_weighted                               [0.898937784522003]
# f1_score_weighted                                  [0.8734461586541715]
# precision_score_micro                               [0.898937784522003]
# norm_macro_recall                                 [0.18281846523181566]
# AUC_macro                                          [0.8930910054144972]
# AUC_weighted                                       [0.8930910054144972]
# precision_score_weighted                           [0.8799158950459306]
# f1_score_micro                                     [0.8989377845220029]
# f1_score_macro                                     [0.6237063604011247]
# recall_score_macro                                 [0.5914092326159078]
# accuracy                                            [0.898937784522003]
# balanced_accuracy                                  [0.5914092326159078]
# log_loss                                           [0.2514857135059798]
# AUC_micro                                          [0.9669289699526344]
# average_precision_score_weighted                   [0.9317067278746238]
# matthews_correlation                              [0.32379302801918675]
# average_precision_score_micro                      [0.9683216698856714]
# weighted_accuracy                                  [0.9752888054537112]
# average_precision_score_macro                      [0.7455384785561991]
# precision_score_macro                              [0.7867377889342119]
#
#                                  3f4389c6-7f46-40f8-ae8e-d4da0defd000_25  \
# recall_score_micro                                  [0.8995447647951441]
# recall_score_weighted                               [0.8995447647951441]
# f1_score_weighted                                   [0.8695793788973059]
# precision_score_micro                               [0.8995447647951441]
# norm_macro_recall                                   [0.1527145654231663]
# AUC_macro                                            [0.926112861607085]
# AUC_weighted                                        [0.9261128616070851]
# precision_score_weighted                            [0.8849783769177578]
# f1_score_micro                                      [0.8995447647951441]
# f1_score_macro                                      [0.6044531098980928]
# recall_score_macro                                  [0.5763572827115832]
# accuracy                                            [0.8995447647951441]
# balanced_accuracy                                   [0.5763572827115832]
# log_loss                                            [0.2236682000120795]
# AUC_micro                                           [0.9737535835092945]
# average_precision_score_weighted                    [0.9458396062576432]
# matthews_correlation                               [0.31289262190926104]
# average_precision_score_micro                       [0.9749096479137287]
# weighted_accuracy                                   [0.9797834745230228]
# average_precision_score_macro                       [0.7921758616931668]
# precision_score_macro                               [0.8205384914463453]
#
#                                  3f4389c6-7f46-40f8-ae8e-d4da0defd000_32  \
# recall_score_micro                                  [0.9132018209408195]
# recall_score_weighted                               [0.9132018209408195]
# f1_score_weighted                                   [0.9096764096913943]
# precision_score_micro                               [0.9132018209408195]
# norm_macro_recall                                  [0.49017777259112316]
# AUC_macro                                           [0.9442592067752529]
# AUC_weighted                                         [0.944259206775253]
# precision_score_weighted                            [0.9074329436294158]
# f1_score_micro                                      [0.9132018209408195]
# f1_score_macro                                      [0.7642816263884915]
# recall_score_macro                                  [0.7450888862955616]
# accuracy                                            [0.9132018209408195]
# balanced_accuracy                                   [0.7450888862955616]
# log_loss                                           [0.18012736943904312]
# AUC_micro                                           [0.9795984627464707]
# average_precision_score_weighted                    [0.9541411484948241]
# matthews_correlation                                [0.5317952742313653]
# average_precision_score_micro                       [0.9805583578526404]
# weighted_accuracy                                    [0.954939715235299]
# average_precision_score_macro                       [0.8198704441305439]
# precision_score_macro                               [0.7884731106837775]
#
#                                  3f4389c6-7f46-40f8-ae8e-d4da0defd000_48  \
# recall_score_micro                                  [0.9040971168437025]
# recall_score_weighted                               [0.9040971168437025]
# f1_score_weighted                                   [0.8814964080412501]
# precision_score_micro                               [0.9040971168437025]
# norm_macro_recall                                   [0.2217841351345844]
# AUC_macro                                           [0.9230531984062151]
# AUC_weighted                                         [0.923053198406215]
# precision_score_weighted                            [0.8898175166222407]
# f1_score_micro                                      [0.9040971168437025]
# f1_score_macro                                      [0.6503363584097662]
# recall_score_macro                                  [0.6108920675672922]
# accuracy                                            [0.9040971168437025]
# balanced_accuracy                                   [0.6108920675672922]
# log_loss                                           [0.22907496550924633]
# AUC_micro                                           [0.9736378980429722]
# average_precision_score_weighted                    [0.9453929821391491]
# matthews_correlation                                [0.3748582669141539]
# average_precision_score_micro                       [0.9745142494075767]
# weighted_accuracy                                   [0.9768919995166504]
# average_precision_score_macro                       [0.7929135412011218]
# precision_score_macro                               [0.8167916410896852]
#
#                                  3f4389c6-7f46-40f8-ae8e-d4da0defd000_53  \
# recall_score_micro                                  [0.9119878603945372]
# recall_score_weighted                               [0.9119878603945372]
# f1_score_weighted                                   [0.9084131426940711]
# precision_score_micro                               [0.9119878603945372]
# norm_macro_recall                                   [0.4840741913912645]
# AUC_macro                                           [0.9446315344903278]
# AUC_weighted                                        [0.9446315344903279]
# precision_score_weighted                            [0.9061089953853695]
# f1_score_micro                                      [0.9119878603945372]
# f1_score_macro                                      [0.7609848659184004]
# recall_score_macro                                  [0.7420370956956323]
# accuracy                                            [0.9119878603945372]
# balanced_accuracy                                   [0.7420370956956323]
# log_loss                                           [0.17906402748691366]
# AUC_micro                                           [0.9796373315894548]
# average_precision_score_weighted                    [0.9540915345785546]
# matthews_correlation                                [0.5251734814462411]
# average_precision_score_micro                       [0.9806034208317105]
# weighted_accuracy                                   [0.9541820381788755]
# average_precision_score_macro                       [0.8194395466063031]
# precision_score_macro                               [0.7848811096721304]
#
#                                  3f4389c6-7f46-40f8-ae8e-d4da0defd000_56  \
# recall_score_micro                                  [0.9125948406676783]
# recall_score_weighted                               [0.9125948406676783]
# f1_score_weighted                                   [0.9087900123862012]
# precision_score_micro                               [0.9125948406676783]
# norm_macro_recall                                   [0.4823894547899683]
# AUC_macro                                           [0.9431190689213795]
# AUC_weighted                                        [0.9431190689213795]
# precision_score_weighted                            [0.9064419404986112]
# f1_score_micro                                      [0.9125948406676783]
# f1_score_macro                                      [0.7613817409356443]
# recall_score_macro                                  [0.7411947273949842]
# accuracy                                            [0.9125948406676783]
# balanced_accuracy                                   [0.7411947273949842]
# log_loss                                           [0.18336134731730297]
# AUC_micro                                            [0.979213090142097]
# average_precision_score_weighted                    [0.9529182178519179]
# matthews_correlation                                [0.5264365575296669]
# average_precision_score_micro                       [0.9801965514804069]
# weighted_accuracy                                    [0.955148852498673]
# average_precision_score_macro                       [0.8149276637285758]
# precision_score_macro                               [0.7872528061629692]
#
#                                  3f4389c6-7f46-40f8-ae8e-d4da0defd000_0  \
# recall_score_micro                                 [0.9116843702579667]
# recall_score_weighted                              [0.9116843702579667]
# f1_score_weighted                                  [0.9091539479147899]
# precision_score_micro                              [0.9116843702579667]
# norm_macro_recall                                  [0.5026785366965085]
# AUC_macro                                          [0.9450464668693166]
# AUC_weighted                                       [0.9450464668693167]
# precision_score_weighted                           [0.9072720074188747]
# f1_score_micro                                     [0.9116843702579667]
# f1_score_macro                                     [0.7653697272147331]
# recall_score_macro                                 [0.7513392683482543]
# accuracy                                           [0.9116843702579667]
# balanced_accuracy                                  [0.7513392683482543]
# log_loss                                          [0.17775706110025447]
# AUC_micro                                           [0.979695082216353]
# average_precision_score_weighted                   [0.9531771295804466]
# matthews_correlation                               [0.5323740218566827]
# average_precision_score_micro                      [0.9806603102489483]
# weighted_accuracy                                  [0.9514937218005303]
# average_precision_score_macro                      [0.8151093723721079]
# precision_score_macro                              [0.7819118765348991]
#
#                                  3f4389c6-7f46-40f8-ae8e-d4da0defd000_64  \
# recall_score_micro                                  [0.9150227617602428]
# recall_score_weighted                               [0.9150227617602428]
# f1_score_weighted                                   [0.9108181543273426]
# precision_score_micro                               [0.9150227617602428]
# norm_macro_recall                                  [0.48512356278723434]
# AUC_macro                                             [0.94683956750709]
# AUC_weighted                                          [0.94683956750709]
# precision_score_weighted                            [0.9085064375916257]
# f1_score_micro                                      [0.9150227617602428]
# f1_score_macro                                      [0.7655319218148326]
# recall_score_macro                                  [0.7425617813936172]
# accuracy                                            [0.9150227617602428]
# balanced_accuracy                                   [0.7425617813936172]
# log_loss                                           [0.19895188237215553]
# AUC_micro                                           [0.9803124704972126]
# average_precision_score_weighted                    [0.9548515891026607]
# matthews_correlation                                [0.5358350000425826]
# average_precision_score_micro                       [0.9812356824191615]
# weighted_accuracy                                   [0.9578401581946913]
# average_precision_score_macro                       [0.8218040197281054]
# precision_score_macro                               [0.7959237288135592]
#
#                                  3f4389c6-7f46-40f8-ae8e-d4da0defd000_27  \
# recall_score_micro                                  [0.9113808801213961]
# recall_score_weighted                               [0.9113808801213961]
# f1_score_weighted                                   [0.9073927516173796]
# precision_score_micro                               [0.9113808801213961]
# norm_macro_recall                                  [0.47391760998949706]
# AUC_macro                                           [0.9430421952886652]
# AUC_weighted                                        [0.9430421952886652]
# precision_score_weighted                            [0.9049425950747526]
# f1_score_micro                                      [0.9113808801213961]
# f1_score_macro                                       [0.757427390076644]
# recall_score_macro                                  [0.7369588049947485]
# accuracy                                            [0.9113808801213961]
# balanced_accuracy                                   [0.7369588049947485]
# log_loss                                           [0.18224214673679842]
# AUC_micro                                           [0.9790717991346616]
# average_precision_score_weighted                    [0.9521050203781521]
# matthews_correlation                                [0.5187332002422864]
# average_precision_score_micro                       [0.9800640147014099]
# weighted_accuracy                                   [0.9546851633380424]
# average_precision_score_macro                       [0.8113142210601237]
# precision_score_macro                                [0.783893368131612]
#
#                                  3f4389c6-7f46-40f8-ae8e-d4da0defd000_31
# recall_score_micro                                  [0.9068285280728376]
# recall_score_weighted                               [0.9068285280728376]
# f1_score_weighted                                    [0.900989610845696]
# precision_score_micro                               [0.9068285280728376]
# norm_macro_recall                                  [0.42379414908298085]
# AUC_macro                                           [0.9259767119202291]
# AUC_weighted                                        [0.9259767119202292]
# precision_score_weighted                            [0.8979210325341437]
# f1_score_micro                                      [0.9068285280728376]
# f1_score_macro                                      [0.7369224531555704]
# recall_score_macro                                  [0.7118970745414904]
# accuracy                                            [0.9068285280728376]
# balanced_accuracy                                   [0.7118970745414904]
# log_loss                                           [0.19848106813194874]
# AUC_micro                                           [0.9749482017403478]
# average_precision_score_weighted                    [0.9437177082499718]
# matthews_correlation                               [0.48083408659079535]
# average_precision_score_micro                        [0.975331900732034]
# weighted_accuracy                                   [0.9552247351780719]
# average_precision_score_macro                       [0.7841150201224165]
# precision_score_macro                               [0.7727756144438112]
#
# [21 rows x 64 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/3f4389c6-7f46-40f8-ae8e-d4da0defd000/model_data
# Downloaded azureml/3f4389c6-7f46-40f8-ae8e-d4da0defd000/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                  silent=True,
#                                                                                                                                  subsample=0.5942105263157895,
#                                                                                                                                  subsample_for_bin=200000,
#                                                                                                                                  subsample_freq=0,
#                                                                                                                                  verbose=-10))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.3333333333333333,
#                                                                                          0.16666666666666666,
#                                                                                          0.16666666666666666,
#                                                                                          0.08333333333333333,
#                                                                                          0.08333333333333333,
#                                                                                          0.08333333333333333,
#                                                                                          0.08333333333333333]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('43',
#                                              Pipeline(memory=None,
#                                                       steps=[('standardscalerwrapper',
#                                                               <azureml.automl.runtime.shared.model_wrappers.StandardScalerWrapper object at 0x7ff527860cf8>),
#                                                              ('xgboostclassifier',
#                                                               XGBoostClassifier(base_score=0.5,
#                                                                                 booster='gbtree',
#                                                                                 colsample_bylevel=1,
#                                                                                 colsample_bynode=1,
#                                                                                 colsample_bytree=1,
#                                                                                 e...
#                                                                                  random_state=None,
#                                                                                  reg_alpha=0.3684210526315789,
#                                                                                  reg_lambda=0.7894736842105263,
#                                                                                  silent=True,
#                                                                                  subsample=0.5942105263157895,
#                                                                                  subsample_for_bin=200000,
#                                                                                  subsample_freq=0,
#                                                                                  verbose=-10))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.3333333333333333, 0.16666666666666666,
#                                          0.16666666666666666, 0.08333333333333333,
#                                          0.08333333333333333, 0.08333333333333333,
#                                          0.08333333333333333]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_1a0971e8_4924_11eb_9da3_000d3aedd3f6row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_1a0971e8_4924_11eb_9da3_000d3aedd3f6row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1a0971e8_4924_11eb_9da3_000d3aedd3f6row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1a0971e8_4924_11eb_9da3_000d3aedd3f6row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_1a0971e8_4924_11eb_9da3_000d3aedd3f6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1a0971e8_4924_11eb_9da3_000d3aedd3f6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1a0971e8_4924_11eb_9da3_000d3aedd3f6row0_col0" class="data row0 col0" >28707</td>
#                         <td id="T_1a0971e8_4924_11eb_9da3_000d3aedd3f6row0_col1" class="data row0 col1" >551</td>
#             </tr>
#             <tr>
#                         <th id="T_1a0971e8_4924_11eb_9da3_000d3aedd3f6level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1a0971e8_4924_11eb_9da3_000d3aedd3f6row1_col0" class="data row1 col0" >1241</td>
#                         <td id="T_1a0971e8_4924_11eb_9da3_000d3aedd3f6row1_col1" class="data row1 col1" >2451</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: 804341ce-aa48-467f-8cc4-523267390091,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/5a4ab2ba-6c51-4805-8155-58759ad589d8/resourceGroups/aml-quickstarts-132152/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-132152/PipelineRuns/PipelineSubmit/804341ce-aa48-467f-8cc4-523267390091)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  2773ef52-5a79-4c81-ad51-aa8df48ae86f

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
